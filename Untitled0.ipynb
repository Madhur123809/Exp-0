# %% [markdown]
# exp 0 : Introduction to python

# %%
#madhurgupta 25070123070
print("Madhur Gupta")
# Out:
# Madhur Gupta
# 2

# %%
print(2)
# Out:
# 2

# %%
print([1,2,3])
# Out:
# [1, 2, 3]

# %%
print("Madhur Gupta")
print(2)
print([1,2,3])
# Out:
# Madhur Gupta
# 2
# [1, 2, 3]
# 43
# [1, 2, 4]
# Madhur Gupta
# 43 [1, 2, 4] Madhur Gupta

# %%
x = 43
y = [1,2,4]
z = "Madhur Gupta"
print(x,y,z,sep="\n")
# Out:
# 43
# [1, 2, 4]
# Madhur Gupta

# %%
x=43
y=[1,2,4]
z="Madhur Gupta"
print(x)
print(y)
print(z)
print(x,y,z)
# Out:
# 43
# [1, 2, 4]
# Madhur Gupta
# 43 [1, 2, 4] Madhur Gupta
